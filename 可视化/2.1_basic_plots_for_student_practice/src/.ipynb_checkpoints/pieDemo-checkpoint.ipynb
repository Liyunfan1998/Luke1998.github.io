# %% [markdown]
#    ## 饼图
#
# **直观显示分布比例的一种可视化方式**

# %%
import matplotlib.pyplot as plt

# The slices will be ordered and plotted counter-clockwise.
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'#label的名称
sizes = [155, 300, 445, 100]#比例数组
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']#颜色数组
explode = (0, 0, 0, 0) # 设定扇形图与中心点的距离

fig = plt.figure() 
fig.canvas.set_window_title('Pie Demo ShowCase')#设置窗口名称，在当前notebook环境下不能显示

#根据相关参数画出饼图
# matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, 
# shadow=False, labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, 
# textprops=None, center=(0, 0), frame=False, hold=None, data=None)

plt.pie(x=sizes, explode=explode, labels=labels, colors=colors, autopct='%.f%%', pctdistance=0.6, 
shadow=False, labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, 
textprops=None, center=(0, 0), frame=False,  data=sizes)


# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')#显示方式，如果为equql,则显示一个正圆

plt.show()
